# %% [markdown]
# <center> <img src="data:image/svg+xml;base64,..." style="width:8.0%"/></center>

# %% [markdown]
# <center><font size=5 face="Helvetica" color=#306998><b>
# MPB Tutorial: Bandstructure of Periodic Dielectric Waveguides
# </b></font></center>

# %% [markdown]
# <center><font face="Helvetica" size=3><b>Ang Chen</b></font></center>
# <center><font face="Helvetica" size=3>February, 2025</font></center>
#
# ***

# %%
import matplotlib.pyplot as plt
import numpy as np

import meep as mp
from meep import mpb

# rc('text', usetex=True)
plt.rcParams["font.family"] = "Helvetica"
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
# Out:
# Using MPI version 3.1, 1 processes

# %% [markdown]
# We simulate the structure of Fig. 5 in Chap. 7 of the book, `Photonic Crystals-Molding the Flow of Light`.

# %%
resolution = 20  # pixels/a

a = 0.500         # units of um
r = 0.25*a        # units of um
h = 0.4*a         # units of um
w = 1.0*a         # units of um

r = r/a          # units of "a"
h = h/a          # units of "a"
w = w/a          # units of "a"

nSi = np.sqrt(12)
Si = mp.Medium(index=nSi)

# %%
geometry_lattice = mp.Lattice(size=mp.Vector3(1,4,4))

geometry = [ mp.Block(center=mp.Vector3(), size=mp.Vector3(mp.inf,w,h), material=Si),
             mp.Cylinder(center=mp.Vector3(), radius=r, height=mp.inf, material=mp.air) ]

num_k = 30
k_points = mp.interpolate(num_k, [mp.Vector3(0,0,0), mp.Vector3(0.5,0,0)])
k_parallel = np.zeros(len(k_points))
k_parallel= np.linspace(0, 1/2, len(k_points))

num_bands = 3

ms = mpb.ModeSolver(geometry_lattice=geometry_lattice,
                    geometry=geometry,
                    k_points=k_points,
                    resolution=resolution,
                    num_bands=num_bands)

# %%
ms.run_yodd_zeven()
yodd_zeven_freqs = ms.all_freqs

ms.run_yeven_zeven()
yeven_zeven_freqs = ms.all_freqs

ms.run_yodd_zodd()
yodd_zodd_freqs = ms.all_freqs

ms.run_yeven_zodd()
yeven_zodd_freqs = ms.all_freqs
# Out:
# Initializing eigensolver data
# Computing 3 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 3 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1,0.4)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0,0,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zevenyodd.
# Initializing fields to random numbers...
# 32 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.016129032258064516, 0.0, 0.0>
#   Vector3<0.03225806451612903, 0.0, 0.0>
#   Vector3<0.04838709677419355, 0.0, 0.0>
#   Vector3<0.06451612903225806, 0.0, 0.0>
#   Vector3<0.08064516129032258, 0.0, 0.0>
#   Vector3<0.0967741935483871, 0.0, 0.0>
#   Vector3<0.11290322580645161, 0.0, 0.0>
#   Vector3<0.12903225806451613, 0.0, 0.0>
#   Vector3<0.14516129032258063, 0.0, 0.0>
#   Vector3<0.16129032258064516, 0.0, 0.0>
#   Vector3<0.1774193548387097, 0.0, 0.0>
#   Vector3<0.1935483870967742, 0.0, 0.0>
#   Vector3<0.2096774193548387, 0.0, 0.0>
#   Vector3<0.22580645161290322, 0.0, 0.0>
#   Vector3<0.24193548387096775, 0.0, 0.0>
#   Vector3<0.25806451612903225, 0.0, 0.0>
#   Vector3<0.27419354838709675, 0.0, 0.0>
#   Vector3<0.29032258064516125, 0.0, 0.0>
#   Vector3<0.3064516129032258, 0.0, 0.0>
#   Vector3<0.3225806451612903, 0.0, 0.0>
#   Vector3<0.3387096774193548, 0.0, 0.0>
#   Vector3<0.3548387096774194, 0.0, 0.0>
#   Vector3<0.3709677419354839, 0.0, 0.0>
#   Vector3<0.3870967741935484, 0.0, 0.0>
#   Vector3<0.4032258064516129, 0.0, 0.0>
#   Vector3<0.4193548387096774, 0.0, 0.0>
#   Vector3<0.43548387096774194, 0.0, 0.0>
#   Vector3<0.45161290322580644, 0.0, 0.0>
#   Vector3<0.46774193548387094, 0.0, 0.0>
#   Vector3<0.4838709677419355, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.08045220375061035
# solve_kpoint (0,0,0):
# zevenyoddfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyodd band 1, zevenyodd band 2, zevenyodd band 3
# Solving for bands 2 to 3...
#     near maximum in trace
#     iteration    1: trace = 1.346183979533041 (197.295% change)
#     iteration    2: trace = 0.1272355075725384 (165.458% change)
#     iteration    3: trace = 0.1110122840654005 (13.6188% change)
#     iteration    4: trace = 0.1057611191853541 (4.84484% change)
#     iteration    5: trace = 0.1045548278394777 (1.14712% change)
#     iteration    6: trace = 0.104321109577265 (0.223787% change)
#     iteration    7: trace = 0.1042037313180733 (0.11258% change)
#     iteration    8: trace = 0.1041786263793332 (0.0240951% change)
#     iteration    9: trace = 0.1041716797378915 (0.00666823% change)
#     iteration   10: trace = 0.1041704366623787 (0.0011933% change)
#     iteration   11: trace = 0.1041701785790128 (0.000247751% change)
#     iteration   12: trace = 0.1041701027468027 (7.27965e-05% change)
#     iteration   13: trace = 0.1041700891136243 (1.30874e-05% change)
#     iteration   14: trace = 0.1041700854841505 (3.48418e-06% change)
# Finished solving for bands 2 to 3 after 14 iterations.
# zevenyoddfreqs:, 1, 0, 0, 0, 0, 0, 0.222525, 0.233779
# elapsed time for k point: 1.5180940628051758
# solve_kpoint (0.016129,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1048059686600726 (0.0899421% change)
#     iteration    2: trace = 0.1047876992759683 (0.0174331% change)
#     iteration    3: trace = 0.1047841686425145 (0.00336938% change)
#     iteration    4: trace = 0.1047827574039342 (0.00134681% change)
#     iteration    5: trace = 0.1047820386919488 (0.000685909% change)
#     iteration    6: trace = 0.1047819327487361 (0.000101108% change)
#     iteration    7: trace = 0.1047819119370035 (1.98619e-05% change)
#     iteration    8: trace = 0.1047819057595132 (5.89557e-06% change)
# Finished solving for bands 1 to 3 after 8 iterations.
# zevenyoddfreqs:, 2, 0.016129, 0, 0, 0.016129, 0.0156534, 0.222554, 0.234535
# elapsed time for k point: 1.1060941219329834
# solve_kpoint (0.0322581,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1066399649614343 (0.0888957% change)
#     iteration    2: trace = 0.1066212232172693 (0.0175763% change)
#     iteration    3: trace = 0.1066174791898471 (0.00351158% change)
#     iteration    4: trace = 0.1066160517700156 (0.00133883% change)
#     iteration    5: trace = 0.1066153565156236 (0.000652113% change)
#     iteration    6: trace = 0.1066152537560829 (9.63835e-05% change)
#     iteration    7: trace = 0.106615229052667 (2.31706e-05% change)
#     iteration    8: trace = 0.1066152200322479 (8.46072e-06% change)
# Finished solving for bands 1 to 3 after 8 iterations.
# zevenyoddfreqs:, 3, 0.0322581, 0, 0, 0.0322581, 0.0312972, 0.222735, 0.236696
# elapsed time for k point: 1.1120247840881348
# solve_kpoint (0.0483871,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1096898687119993 (0.0880227% change)
#     iteration    2: trace = 0.1096701180708769 (0.0180075% change)
#     iteration    3: trace = 0.1096659757946983 (0.0037771% change)
#     iteration    4: trace = 0.1096644697172949 (0.00137334% change)
#     iteration    5: trace = 0.1096637977698503 (0.000612732% change)
#     iteration    6: trace = 0.1096637003469529 (8.88378e-05% change)
#     iteration    7: trace = 0.1096636718315202 (2.60026e-05% change)
#     iteration    8: trace = 0.1096636603133562 (1.05032e-05% change)
#     iteration    9: trace = 0.1096636573972208 (2.65916e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyoddfreqs:, 4, 0.0483871, 0, 0, 0.0483871, 0.0469211, 0.223237, 0.240057
# elapsed time for k point: 1.2391023635864258
# solve_kpoint (0.0645161,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1139453685827666 (0.087097% change)
#     iteration    2: trace = 0.1139241494384033 (0.0186239% change)
#     iteration    3: trace = 0.1139194804174093 (0.00409844% change)
#     iteration    4: trace = 0.1139178686596864 (0.00141483% change)
#     iteration    5: trace = 0.1139172198460352 (0.000569547% change)
#     iteration    6: trace = 0.1139171300295877 (7.88436e-05% change)
#     iteration    7: trace = 0.1139171002341846 (2.61553e-05% change)
#     iteration    8: trace = 0.1139170875826924 (1.11059e-05% change)
#     iteration    9: trace = 0.1139170843117998 (2.87129e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyoddfreqs:, 5, 0.0645161, 0, 0, 0.0645161, 0.0625134, 0.224173, 0.244449
# elapsed time for k point: 1.2951321601867676
# solve_kpoint (0.0806452,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1193929918859635 (0.0859786% change)
#     iteration    2: trace = 0.1193699510684459 (0.0193002% change)
#     iteration    3: trace = 0.1193646912859668 (0.00440638% change)
#     iteration    4: trace = 0.1193629828153033 (0.00143131% change)
#     iteration    5: trace = 0.1193623575870663 (0.000523806% change)
#     iteration    6: trace = 0.1193622769781765 (6.75329e-05% change)
#     iteration    7: trace = 0.1193622489546787 (2.34777e-05% change)
#     iteration    8: trace = 0.1193622367759952 (1.02031e-05% change)
#     iteration    9: trace = 0.1193622334612795 (2.77702e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyoddfreqs:, 6, 0.0806452, 0, 0, 0.0806452, 0.07806, 0.225589, 0.249757
# elapsed time for k point: 1.248002052307129
# solve_kpoint (0.0967742,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1260169713672369 (0.0845264% change)
#     iteration    2: trace = 0.1259918770498791 (0.0199154% change)
#     iteration    3: trace = 0.125986035471038 (0.00463658% change)
#     iteration    4: trace = 0.1259842517189958 (0.00141584% change)
#     iteration    5: trace = 0.1259836512217548 (0.000476646% change)
#     iteration    6: trace = 0.1259835806029152 (5.6054e-05% change)
#     iteration    7: trace = 0.1259835570482755 (1.86966e-05% change)
#     iteration    8: trace = 0.1259835469054713 (8.0509e-06% change)
# Finished solving for bands 1 to 3 after 8 iterations.
# zevenyoddfreqs:, 7, 0.0967742, 0, 0, 0.0967742, 0.0935429, 0.227485, 0.255898
# elapsed time for k point: 1.1200718879699707
# solve_kpoint (0.112903,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.133800149724008 (0.0826586% change)
#     iteration    2: trace = 0.1337728989414019 (0.0203689% change)
#     iteration    3: trace = 0.1337665470933354 (0.00474835% change)
#     iteration    4: trace = 0.1337647339660626 (0.00135545% change)
#     iteration    5: trace = 0.133764163234359 (0.000426669% change)
#     iteration    6: trace = 0.133764102121696 (4.56869e-05% change)
#     iteration    7: trace = 0.1337640838863627 (1.36325e-05% change)
#     iteration    8: trace = 0.1337640766284283 (5.42592e-06% change)
# Finished solving for bands 1 to 3 after 8 iterations.
# zevenyoddfreqs:, 8, 0.112903, 0, 0, 0.112903, 0.108938, 0.229846, 0.262806
# elapsed time for k point: 1.1490581035614014
# solve_kpoint (0.129032,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1427249122984925 (0.0802724% change)
#     iteration    2: trace = 0.1426955634377218 (0.0205654% change)
#     iteration    3: trace = 0.1426888273135796 (0.00472074% change)
#     iteration    4: trace = 0.1426870023393815 (0.001279% change)
#     iteration    5: trace = 0.1426864586374073 (0.000381046% change)
#     iteration    6: trace = 0.1426864063339944 (3.66562e-05% change)
#     iteration    7: trace = 0.142686393947119 (8.68119e-06% change)
# Finished solving for bands 1 to 3 after 7 iterations.
# zevenyoddfreqs:, 9, 0.129032, 0, 0, 0.129032, 0.124213, 0.232658, 0.270422
# elapsed time for k point: 1.037916898727417
# solve_kpoint (0.145161,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.152774025611648 (0.0774159% change)
#     iteration    2: trace = 0.1527427043428152 (0.0205038% change)
#     iteration    3: trace = 0.152735715502412 (0.00457567% change)
#     iteration    4: trace = 0.1527338812737396 (0.00120092% change)
#     iteration    5: trace = 0.1527333577822883 (0.000342748% change)
#     iteration    6: trace = 0.1527333118354273 (3.00831e-05% change)
#     iteration    7: trace = 0.1527333034520158 (5.48892e-06% change)
# Finished solving for bands 1 to 3 after 7 iterations.
# zevenyoddfreqs:, 10, 0.145161, 0, 0, 0.145161, 0.139321, 0.235914, 0.278689
# elapsed time for k point: 1.0830421447753906
# solve_kpoint (0.16129,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1639308502380206 (0.0741359% change)
#     iteration    2: trace = 0.1638978245776841 (0.0201481% change)
#     iteration    3: trace = 0.1638907268626494 (0.00433067% change)
#     iteration    4: trace = 0.1638889300418231 (0.00109636% change)
#     iteration    5: trace = 0.1638884286555717 (0.000305931% change)
#     iteration    6: trace = 0.1638883858777375 (2.61018e-05% change)
#     iteration    7: trace = 0.1638883787276777 (4.36276e-06% change)
# Finished solving for bands 1 to 3 after 7 iterations.
# zevenyoddfreqs:, 11, 0.16129, 0, 0, 0.16129, 0.154194, 0.239637, 0.287553
# elapsed time for k point: 0.9804418087005615
# solve_kpoint (0.177419,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.17618005237489 (0.0705753% change)
#     iteration    2: trace = 0.1761455638094963 (0.0195777% change)
#     iteration    3: trace = 0.1761384589702176 (0.00403359% change)
#     iteration    4: trace = 0.1761366993211015 (0.00099902% change)
#     iteration    5: trace = 0.1761362068493152 (0.000279597% change)
#     iteration    6: trace = 0.1761361601908659 (2.649e-05% change)
#     iteration    7: trace = 0.1761361479450039 (6.9525e-06% change)
# Finished solving for bands 1 to 3 after 7 iterations.
# zevenyoddfreqs:, 12, 0.177419, 0, 0, 0.177419, 0.16873, 0.243883, 0.296963
# elapsed time for k point: 0.9693000316619873
# solve_kpoint (0.193548,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1895071244808215 (0.066879% change)
#     iteration    2: trace = 0.1894713823776481 (0.0188623% change)
#     iteration    3: trace = 0.1894643317873319 (0.00372126% change)
#     iteration    4: trace = 0.189462588832131 (0.000919943% change)
#     iteration    5: trace = 0.1894620822024118 (0.000267404% change)
#     iteration    6: trace = 0.1894620191225677 (3.32942e-05% change)
#     iteration    7: trace = 0.1894619862378868 (1.73569e-05% change)
#     iteration    8: trace = 0.1894619709821295 (8.05215e-06% change)
# Finished solving for bands 1 to 3 after 8 iterations.
# zevenyoddfreqs:, 13, 0.193548, 0, 0, 0.193548, 0.182778, 0.248767, 0.30687
# elapsed time for k point: 1.1145410537719727
# solve_kpoint (0.209677,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2038979109068923 (0.0632018% change)
#     iteration    2: trace = 0.2038610912570016 (0.0180595% change)
#     iteration    3: trace = 0.203854112898102 (0.00342315% change)
#     iteration    4: trace = 0.2038524008347242 (0.000839851% change)
#     iteration    5: trace = 0.2038518691300266 (0.000260829% change)
#     iteration    6: trace = 0.2038517773842329 (4.50061e-05% change)
#     iteration    7: trace = 0.203851705685927 (3.51718e-05% change)
#     iteration    8: trace = 0.2038516716634746 (1.66898e-05% change)
#     iteration    9: trace = 0.2038516545441262 (8.39794e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyoddfreqs:, 14, 0.209677, 0, 0, 0.209677, 0.196112, 0.254479, 0.317225
# elapsed time for k point: 1.2438561916351318
# solve_kpoint (0.225806,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2193384321305479 (0.0596188% change)
#     iteration    2: trace = 0.2193005376796425 (0.0172782% change)
#     iteration    3: trace = 0.21929354857697 (0.00318705% change)
#     iteration    4: trace = 0.219291757466856 (0.000816767% change)
#     iteration    5: trace = 0.219291161123066 (0.000271941% change)
#     iteration    6: trace = 0.2192910278817521 (6.076e-05% change)
#     iteration    7: trace = 0.2192909035961906 (5.66761e-05% change)
#     iteration    8: trace = 0.2192908485723968 (2.50917e-05% change)
#     iteration    9: trace = 0.2192908205885921 (1.2761e-05% change)
#     iteration   10: trace = 0.2192908094795702 (5.06589e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyoddfreqs:, 15, 0.225806, 0, 0, 0.225806, 0.208435, 0.26129, 0.327984
# elapsed time for k point: 1.3971362113952637
# solve_kpoint (0.241935,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2358134138652891 (0.0563209% change)
#     iteration    2: trace = 0.2357742007944676 (0.0166302% change)
#     iteration    3: trace = 0.2357670238984825 (0.00304402% change)
#     iteration    4: trace = 0.2357650893543279 (0.000820535% change)
#     iteration    5: trace = 0.2357643951741058 (0.000294438% change)
#     iteration    6: trace = 0.2357641909413289 (8.66258e-05% change)
#     iteration    7: trace = 0.2357639879667487 (8.60922e-05% change)
#     iteration    8: trace = 0.2357639050301675 (3.51778e-05% change)
#     iteration    9: trace = 0.2357638615043979 (1.84616e-05% change)
#     iteration   10: trace = 0.2357638458513126 (6.63931e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyoddfreqs:, 16, 0.241935, 0, 0, 0.241935, 0.219423, 0.269495, 0.339102
# elapsed time for k point: 1.3715810775756836
# solve_kpoint (0.258065,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2533052400442959 (0.053432% change)
#     iteration    2: trace = 0.2532642205775119 (0.016195% change)
#     iteration    3: trace = 0.2532565484060515 (0.00302936% change)
#     iteration    4: trace = 0.2532542678746604 (0.000900487% change)
#     iteration    5: trace = 0.2532533613936109 (0.000357934% change)
#     iteration    6: trace = 0.2532530268603127 (0.000132094% change)
#     iteration    7: trace = 0.2532527075581457 (0.00012608% change)
#     iteration    8: trace = 0.2532525868533092 (4.76618e-05% change)
#     iteration    9: trace = 0.253252521421807 (2.58365e-05% change)
#     iteration   10: trace = 0.2532524998420416 (8.52105e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyoddfreqs:, 17, 0.258065, 0, 0, 0.258065, 0.228865, 0.27928, 0.350536
# elapsed time for k point: 1.4134578704833984
# solve_kpoint (0.274194,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2717914844038318 (0.0510414% change)
#     iteration    2: trace = 0.2717477456391163 (0.0160941% change)
#     iteration    3: trace = 0.2717389915146027 (0.00322147% change)
#     iteration    4: trace = 0.2717359748505889 (0.00111014% change)
#     iteration    5: trace = 0.2717346408643269 (0.000490914% change)
#     iteration    6: trace = 0.2717340505244911 (0.000217249% change)
#     iteration    7: trace = 0.2717335374584426 (0.000188812% change)
#     iteration    8: trace = 0.2717333520720825 (6.82236e-05% change)
#     iteration    9: trace = 0.2717332551934536 (3.56521e-05% change)
#     iteration   10: trace = 0.2717332296104094 (9.41476e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyoddfreqs:, 18, 0.274194, 0, 0, 0.274194, 0.236801, 0.29058, 0.362245
# elapsed time for k point: 1.4328172206878662
# solve_kpoint (0.290323,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2912401226675437 (0.0493529% change)
#     iteration    2: trace = 0.2911916918643169 (0.0166305% change)
#     iteration    3: trace = 0.2911803732237269 (0.00388708% change)
#     iteration    4: trace = 0.2911753678933847 (0.00171899% change)
#     iteration    5: trace = 0.2911726919917084 (0.000919004% change)
#     iteration    6: trace = 0.2911709892843242 (0.000584777% change)
#     iteration    7: trace = 0.2911693629131855 (0.000558564% change)
#     iteration    8: trace = 0.291168490710693 (0.000299552% change)
#     iteration    9: trace = 0.2911679088761822 (0.000199828% change)
#     iteration   10: trace = 0.2911676858851495 (7.65851e-05% change)
#     iteration   11: trace = 0.2911674669527365 (7.51912e-05% change)
#     iteration   12: trace = 0.2911672974992932 (5.81979e-05% change)
#     iteration   13: trace = 0.2911671415940748 (5.35449e-05% change)
#     iteration   14: trace = 0.2911670220524818 (4.1056e-05% change)
#     iteration   15: trace = 0.2911669758754167 (1.58593e-05% change)
#     iteration   16: trace = 0.2911669631146767 (4.38262e-06% change)
# Finished solving for bands 1 to 3 after 16 iterations.
# zevenyoddfreqs:, 19, 0.290323, 0, 0, 0.290323, 0.243485, 0.30311, 0.374174
# elapsed time for k point: 2.127385139465332
# solve_kpoint (0.306452,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3115707620937991 (0.0496027% change)
#     iteration    2: trace = 0.311508146775908 (0.0200987% change)
#     iteration    3: trace = 0.3114830648196426 (0.00805211% change)
#     iteration    4: trace = 0.3114593533282811 (0.00761274% change)
#     iteration    5: trace = 0.3114299929815936 (0.00942715% change)
#     large trace change predicted (0.0262854%)
#     iteration    6: trace = 0.3113473514524113 (0.0265397% change)
#     large trace change predicted (0.170174%)
#     iteration    7: trace = 0.3109488244072565 (0.128083% change)
#     iteration    8: trace = 0.3102747666628701 (0.21701% change)
#     iteration    9: trace = 0.3094571961789273 (0.263846% change)
#     iteration   10: trace = 0.3089432797775691 (0.166208% change)
#     iteration   11: trace = 0.3086755193273349 (0.0867074% change)
#     iteration   12: trace = 0.3084475325009906 (0.073887% change)
#     iteration   13: trace = 0.3082287333357602 (0.0709608% change)
#     iteration   14: trace = 0.3079970499362346 (0.0751943% change)
#     iteration   15: trace = 0.3077916228200261 (0.06672% change)
#     iteration   16: trace = 0.3076619856410598 (0.0421274% change)
#     iteration   17: trace = 0.3075935919450585 (0.0222326% change)
#     iteration   18: trace = 0.3075528468599611 (0.0132473% change)
#     iteration   19: trace = 0.3075215032147894 (0.0101918% change)
#     iteration   20: trace = 0.3074964232283722 (0.00815586% change)
#     iteration   21: trace = 0.3074799023268125 (0.00537286% change)
#     iteration   22: trace = 0.3074684574989202 (0.00372221% change)
#     iteration   23: trace = 0.3074606343463577 (0.00254441% change)
#     iteration   24: trace = 0.3074545268488478 (0.00198645% change)
#     iteration   25: trace = 0.3074482447530245 (0.00204328% change)
#     iteration   26: trace = 0.3074421986014918 (0.00196658% change)
#     iteration   27: trace = 0.3074372872593069 (0.0015975% change)
#     iteration   28: trace = 0.3074336797722352 (0.00117341% change)
#     iteration   29: trace = 0.3074313263183833 (0.000765519% change)
#     iteration   30: trace = 0.3074292374595669 (0.000679458% change)
#     iteration   31: trace = 0.307427010961435 (0.000724234% change)
#     iteration   32: trace = 0.3074249747240669 (0.00066235% change)
#     iteration   33: trace = 0.307423320697426 (0.000538028% change)
#     iteration   34: trace = 0.3074221680251337 (0.000374947% change)
#     iteration   35: trace = 0.3074214036139045 (0.000248652% change)
#     iteration   36: trace = 0.3074207718465905 (0.000205506% change)
#     iteration   37: trace = 0.3074202658735508 (0.000164587% change)
#     iteration   38: trace = 0.3074199266004044 (0.000110361% change)
#     iteration   39: trace = 0.3074197371353872 (6.16307e-05% change)
#     iteration   40: trace = 0.307419625687707 (3.62526e-05% change)
#     iteration   41: trace = 0.3074195462489833 (2.58405e-05% change)
#     iteration   42: trace = 0.3074194847090167 (2.00182e-05% change)
#     iteration   43: trace = 0.3074194410495481 (1.42019e-05% change)
#     iteration   44: trace = 0.3074194184019762 (7.36699e-06% change)
# Finished solving for bands 1 to 3 after 44 iterations.
# zevenyoddfreqs:, 20, 0.306452, 0, 0, 0.306452, 0.249234, 0.316509, 0.380951
# elapsed time for k point: 5.659289121627808
# solve_kpoint (0.322581,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3168344952217523 (0.065678% change)
#     iteration    2: trace = 0.3167392538542031 (0.0300648% change)
#     iteration    3: trace = 0.3166931174430512 (0.0145671% change)
#     iteration    4: trace = 0.3166551260514829 (0.011997% change)
#     iteration    5: trace = 0.3166414002563148 (0.00433471% change)
#     iteration    6: trace = 0.3166343078665966 (0.00223991% change)
#     iteration    7: trace = 0.3166305974503004 (0.00117184% change)
#     iteration    8: trace = 0.3166284459227179 (0.000679509% change)
#     iteration    9: trace = 0.3166273676641623 (0.000340544% change)
#     iteration   10: trace = 0.3166270015063621 (0.000115643% change)
#     iteration   11: trace = 0.3166268618610091 (4.41041e-05% change)
#     iteration   12: trace = 0.3166268365804092 (7.98435e-06% change)
# Finished solving for bands 1 to 3 after 12 iterations.
# zevenyoddfreqs:, 21, 0.322581, 0, 0, 0.322581, 0.254309, 0.330441, 0.377839
# elapsed time for k point: 1.5963380336761475
# solve_kpoint (0.33871,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3263500179370226 (0.0546157% change)
#     iteration    2: trace = 0.3262936989318431 (0.0172587% change)
#     iteration    3: trace = 0.3262822411383813 (0.00351156% change)
#     iteration    4: trace = 0.3262753293244143 (0.00211838% change)
#     iteration    5: trace = 0.3262728593485047 (0.000757025% change)
#     iteration    6: trace = 0.3262720666175584 (0.000242966% change)
#     iteration    7: trace = 0.326271679778115 (0.000118564% change)
#     iteration    8: trace = 0.3262715840443341 (2.93417e-05% change)
#     iteration    9: trace = 0.3262715487306588 (1.08234e-05% change)
#     iteration   10: trace = 0.3262715411515166 (2.32296e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyoddfreqs:, 22, 0.33871, 0, 0, 0.33871, 0.258889, 0.344531, 0.374896
# elapsed time for k point: 1.3671131134033203
# solve_kpoint (0.354839,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3364935422963025 (0.0511257% change)
#     iteration    2: trace = 0.3364433299483002 (0.0149233% change)
#     iteration    3: trace = 0.3364356542031155 (0.00228146% change)
#     iteration    4: trace = 0.3364319516649253 (0.00110053% change)
#     iteration    5: trace = 0.3364307206351537 (0.000365908% change)
#     iteration    6: trace = 0.3364303995879716 (9.54275e-05% change)
#     iteration    7: trace = 0.3364302329457945 (4.95324e-05% change)
#     iteration    8: trace = 0.3364301942289966 (1.15081e-05% change)
#     iteration    9: trace = 0.3364301836383662 (3.14794e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyoddfreqs:, 23, 0.354839, 0, 0, 0.354839, 0.263083, 0.357694, 0.373192
# elapsed time for k point: 1.2348198890686035
# solve_kpoint (0.370968,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3471768488383391 (0.0488042% change)
#     iteration    2: trace = 0.3471285382388507 (0.0139162% change)
#     iteration    3: trace = 0.347121856550157 (0.00192486% change)
#     iteration    4: trace = 0.347118886085783 (0.000855745% change)
#     iteration    5: trace = 0.3471179064847962 (0.000282209% change)
#     iteration    6: trace = 0.347117669666001 (6.82243e-05% change)
#     iteration    7: trace = 0.3471175420673668 (3.67595e-05% change)
#     iteration    8: trace = 0.3471175099154748 (9.26254e-06% change)
# Finished solving for bands 1 to 3 after 8 iterations.
# zevenyoddfreqs:, 24, 0.370968, 0, 0, 0.370968, 0.266946, 0.363819, 0.378805
# elapsed time for k point: 1.0805060863494873
# solve_kpoint (0.387097,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3583913134892633 (0.0471688% change)
#     iteration    2: trace = 0.3583428324697855 (0.0135283% change)
#     iteration    3: trace = 0.3583359499730121 (0.00192066% change)
#     iteration    4: trace = 0.3583327610286773 (0.000889935% change)
#     iteration    5: trace = 0.3583317004346204 (0.000295981% change)
#     iteration    6: trace = 0.3583313994441932 (8.39977e-05% change)
#     iteration    7: trace = 0.3583312398092755 (4.45495e-05% change)
#     iteration    8: trace = 0.3583312002681586 (1.10348e-05% change)
#     iteration    9: trace = 0.3583311884225276 (3.30578e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyoddfreqs:, 25, 0.387097, 0, 0, 0.387097, 0.270499, 0.362498, 0.392118
# elapsed time for k point: 1.2087712287902832
# solve_kpoint (0.403226,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3701218943062912 (0.0460469% change)
#     iteration    2: trace = 0.3700716112377036 (0.0135865% change)
#     iteration    3: trace = 0.3700635208957985 (0.00218618% change)
#     iteration    4: trace = 0.3700592091849231 (0.00116513% change)
#     iteration    5: trace = 0.3700577012534048 (0.000407485% change)
#     iteration    6: trace = 0.3700572183562819 (0.000130492% change)
#     iteration    7: trace = 0.3700569906091228 (6.15438e-05% change)
#     iteration    8: trace = 0.3700569381433567 (1.41778e-05% change)
#     iteration    9: trace = 0.3700569215096844 (4.4949e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyoddfreqs:, 26, 0.403226, 0, 0, 0.403226, 0.273734, 0.360065, 0.406792
# elapsed time for k point: 1.2335729598999023
# solve_kpoint (0.419355,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3823415379767705 (0.045563% change)
#     iteration    2: trace = 0.3822871233583613 (0.014233% change)
#     iteration    3: trace = 0.382276205343933 (0.00285601% change)
#     iteration    4: trace = 0.3822694105273774 (0.00177748% change)
#     iteration    5: trace = 0.3822670642415754 (0.00061378% change)
#     iteration    6: trace = 0.382266248696434 (0.000213345% change)
#     iteration    7: trace = 0.3822659214678368 (8.56023e-05% change)
#     iteration    8: trace = 0.3822658473390575 (1.93919e-05% change)
#     iteration    9: trace = 0.3822658216976433 (6.70774e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyoddfreqs:, 27, 0.419355, 0, 0, 0.419355, 0.276622, 0.357616, 0.421731
# elapsed time for k point: 1.2225310802459717
# solve_kpoint (0.435484,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3950022325686042 (0.0459032% change)
#     iteration    2: trace = 0.3949400347968022 (0.0157474% change)
#     iteration    3: trace = 0.3949230586092786 (0.00429851% change)
#     iteration    4: trace = 0.3949110592057598 (0.00303846% change)
#     iteration    5: trace = 0.3949071544294033 (0.000988779% change)
#     iteration    6: trace = 0.3949057400412324 (0.000358158% change)
#     iteration    7: trace = 0.3949052500171177 (0.000124086% change)
#     iteration    8: trace = 0.3949051316856785 (2.99645e-05% change)
#     iteration    9: trace = 0.3949050868779799 (1.13464e-05% change)
#     iteration   10: trace = 0.3949050702115199 (4.22037e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyoddfreqs:, 28, 0.435484, 0, 0, 0.435484, 0.279117, 0.355398, 0.436682
# elapsed time for k point: 1.365149974822998
# solve_kpoint (0.451613,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4080161378582485 (0.047555% change)
#     iteration    2: trace = 0.4079391197218611 (0.018878% change)
#     iteration    3: trace = 0.407908258206004 (0.00756551% change)
#     iteration    4: trace = 0.4078849500865748 (0.00571422% change)
#     iteration    5: trace = 0.4078781134275686 (0.00167614% change)
#     iteration    6: trace = 0.4078754927777549 (0.00064251% change)
#     iteration    7: trace = 0.407874677783579 (0.000199815% change)
#     iteration    8: trace = 0.4078744535571102 (5.49744e-05% change)
#     iteration    9: trace = 0.4078743650627866 (2.16965e-05% change)
#     iteration   10: trace = 0.4078743322285581 (8.05008e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyoddfreqs:, 29, 0.451613, 0, 0, 0.451613, 0.281158, 0.353537, 0.451482
# elapsed time for k point: 1.3644781112670898
# solve_kpoint (0.467742,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4212072385163027 (0.0517932% change)
#     iteration    2: trace = 0.4210985319996361 (0.0258117% change)
#     iteration    3: trace = 0.421031662341289 (0.0158811% change)
#     iteration    4: trace = 0.4209806961721896 (0.0121058% change)
#     iteration    5: trace = 0.4209666781719038 (0.0033299% change)
#     iteration    6: trace = 0.4209608599342211 (0.00138212% change)
#     iteration    7: trace = 0.4209591229379436 (0.000412627% change)
#     iteration    8: trace = 0.4209585566444914 (0.000134525% change)
#     iteration    9: trace = 0.4209583357933639 (5.24639e-05% change)
#     iteration   10: trace = 0.4209582551614409 (1.91544e-05% change)
#     iteration   11: trace = 0.4209582341223914 (4.99789e-06% change)
# Finished solving for bands 1 to 3 after 11 iterations.
# zevenyoddfreqs:, 30, 0.467742, 0, 0, 0.467742, 0.282681, 0.352128, 0.465892
# elapsed time for k point: 1.4607348442077637
# solve_kpoint (0.483871,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4341533783891416 (0.0627579% change)
#     iteration    2: trace = 0.4339582282687361 (0.0449597% change)
#     iteration    3: trace = 0.4337676525471689 (0.0439253% change)
#     iteration    4: trace = 0.4336247835309223 (0.0329422% change)
#     iteration    5: trace = 0.4335833705519956 (0.00955087% change)
#     iteration    6: trace = 0.4335624824756917 (0.00481766% change)
#     iteration    7: trace = 0.4335549713005242 (0.00173245% change)
#     iteration    8: trace = 0.4335510417247084 (0.000906366% change)
#     iteration    9: trace = 0.4335491647544825 (0.00043293% change)
#     iteration   10: trace = 0.4335482562402529 (0.000209553% change)
#     iteration   11: trace = 0.4335478545842377 (9.26439e-05% change)
#     iteration   12: trace = 0.4335476820002556 (3.98074e-05% change)
#     iteration   13: trace = 0.4335476153723358 (1.53681e-05% change)
#     iteration   14: trace = 0.4335475856509038 (6.8554e-06% change)
# Finished solving for bands 1 to 3 after 14 iterations.
# zevenyoddfreqs:, 31, 0.483871, 0, 0, 0.483871, 0.283624, 0.351248, 0.479301
# elapsed time for k point: 1.8406291007995605
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4453264792218784 (0.106232% change)
#     iteration    2: trace = 0.4446917038538383 (0.142643% change)
#     iteration    3: trace = 0.4436348238118518 (0.237949% change)
#     iteration    4: trace = 0.4428436468962283 (0.178499% change)
#     iteration    5: trace = 0.442524845284663 (0.0720156% change)
#     iteration    6: trace = 0.4422577388193461 (0.0603779% change)
#     iteration    7: trace = 0.4420720864222958 (0.0419871% change)
#     iteration    8: trace = 0.4418784438428234 (0.043813% change)
#     iteration    9: trace = 0.4417578493949628 (0.027295% change)
#     iteration   10: trace = 0.4416940451264738 (0.0144443% change)
#     iteration   11: trace = 0.4416657207422262 (0.00641288% change)
#     iteration   12: trace = 0.4416552818675198 (0.00236355% change)
#     iteration   13: trace = 0.4416515210672802 (0.000851528% change)
#     iteration   14: trace = 0.4416499755242115 (0.000349947% change)
#     iteration   15: trace = 0.4416496721010447 (6.87022e-05% change)
#     iteration   16: trace = 0.4416495233903742 (3.36716e-05% change)
#     iteration   17: trace = 0.4416494610367945 (1.41183e-05% change)
#     iteration   18: trace = 0.4416494306298524 (6.88486e-06% change)
# Finished solving for bands 1 to 3 after 18 iterations.
# zevenyoddfreqs:, 32, 0.5, 0, 0, 0.5, 0.283945, 0.350948, 0.487709
# elapsed time for k point: 2.349679708480835
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2839448326137415 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.22252475297297095 at Vector3<0.0, 0.0, 0.0> to 0.36381863110789964 at Vector3<0.3709677419354839, 0.0, 0.0>
# Band 3 range: 0.23377942552429715 at Vector3<0.0, 0.0, 0.0> to 0.4877092889616469 at Vector3<0.5, 0.0, 0.0>
# total elapsed time for run: 47.02525997161865
# done
# Initializing eigensolver data
# Computing 3 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 80 x 80.
# Solving for 3 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 4)
# Cell volume = 16
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.25)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1,0.4)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0,0,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zevenyeven.
# Initializing fields to random numbers...
# 32 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.016129032258064516, 0.0, 0.0>
#   Vector3<0.03225806451612903, 0.0, 0.0>
#   Vector3<0.04838709677419355, 0.0, 0.0>
#   Vector3<0.06451612903225806, 0.0, 0.0>
#   Vector3<0.08064516129032258, 0.0, 0.0>
#   Vector3<0.0967741935483871, 0.0, 0.0>
#   Vector3<0.11290322580645161, 0.0, 0.0>
#   Vector3<0.12903225806451613, 0.0, 0.0>
#   Vector3<0.14516129032258063, 0.0, 0.0>
#   Vector3<0.16129032258064516, 0.0, 0.0>
#   Vector3<0.1774193548387097, 0.0, 0.0>
#   Vector3<0.1935483870967742, 0.0, 0.0>
#   Vector3<0.2096774193548387, 0.0, 0.0>
#   Vector3<0.22580645161290322, 0.0, 0.0>
#   Vector3<0.24193548387096775, 0.0, 0.0>
#   Vector3<0.25806451612903225, 0.0, 0.0>
#   Vector3<0.27419354838709675, 0.0, 0.0>
#   Vector3<0.29032258064516125, 0.0, 0.0>
#   Vector3<0.3064516129032258, 0.0, 0.0>
#   Vector3<0.3225806451612903, 0.0, 0.0>
#   Vector3<0.3387096774193548, 0.0, 0.0>
#   Vector3<0.3548387096774194, 0.0, 0.0>
#   Vector3<0.3709677419354839, 0.0, 0.0>
#   Vector3<0.3870967741935484, 0.0, 0.0>
#   Vector3<0.4032258064516129, 0.0, 0.0>
#   Vector3<0.4193548387096774, 0.0, 0.0>
#   Vector3<0.43548387096774194, 0.0, 0.0>
#   Vector3<0.45161290322580644, 0.0, 0.0>
#   Vector3<0.46774193548387094, 0.0, 0.0>
#   Vector3<0.4838709677419355, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.05036497116088867
# solve_kpoint (0,0,0):
# zevenyevenfreqs:, k index, k1, k2, k3, kmag/2pi, zevenyeven band 1, zevenyeven band 2, zevenyeven band 3
# Solving for bands 1 to 3...
#     near maximum in trace
#     iteration    1: trace = 3.493972168281965 (195.3% change)
#     iteration    2: trace = 0.2499466025602142 (173.296% change)
#     iteration    3: trace = 0.2053030051943213 (19.6128% change)
#     iteration    4: trace = 0.1941536847620536 (5.58224% change)
#     iteration    5: trace = 0.1926117604693292 (0.797343% change)
#     iteration    6: trace = 0.1918717664421655 (0.384929% change)
#     iteration    7: trace = 0.1916458616546107 (0.117807% change)
#     iteration    8: trace = 0.191511364120485 (0.0702049% change)
#     iteration    9: trace = 0.1914559989822613 (0.0289138% change)
#     iteration   10: trace = 0.1914403154954257 (0.00819203% change)
#     iteration   11: trace = 0.1914356853950131 (0.00241859% change)
#     iteration   12: trace = 0.1914347168810392 (0.000505923% change)
#     iteration   13: trace = 0.191434436506972 (0.000146459% change)
#     iteration   14: trace = 0.1914343491412941 (4.56374e-05% change)
#     iteration   15: trace = 0.1914343008509047 (2.52256e-05% change)
#     iteration   16: trace = 0.1914342728160451 (1.46446e-05% change)
#     iteration   17: trace = 0.1914342719247569 (4.65584e-07% change)
# Finished solving for bands 1 to 3 after 17 iterations.
# zevenyevenfreqs:, 1, 0, 0, 0, 0, 0.179912, 0.249736, 0.310963
# elapsed time for k point: 2.2998099327087402
# solve_kpoint (0.016129,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1922303792440822 (0.0788132% change)
#     iteration    2: trace = 0.1921888805988424 (0.0215903% change)
#     iteration    3: trace = 0.1921825412247645 (0.00329857% change)
#     iteration    4: trace = 0.192176925293035 (0.00292223% change)
#     iteration    5: trace = 0.1921753502056615 (0.000819606% change)
#     iteration    6: trace = 0.1921748511038273 (0.000259712% change)
#     iteration    7: trace = 0.1921747744195113 (3.99034e-05% change)
#     iteration    8: trace = 0.1921747609293964 (7.01971e-06% change)
# Finished solving for bands 1 to 3 after 8 iterations.
# zevenyevenfreqs:, 2, 0.016129, 0, 0, 0.016129, 0.180573, 0.25025, 0.311357
# elapsed time for k point: 1.0996301174163818
# solve_kpoint (0.0322581,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1944500916622717 (0.0766863% change)
#     iteration    2: trace = 0.1944093263621491 (0.0209666% change)
#     iteration    3: trace = 0.19440321760581 (0.00314226% change)
#     iteration    4: trace = 0.1943978544061951 (0.00275884% change)
#     iteration    5: trace = 0.1943963054152922 (0.000796818% change)
#     iteration    6: trace = 0.1943957875712767 (0.000266386% change)
#     iteration    7: trace = 0.1943956907259624 (4.98186e-05% change)
#     iteration    8: trace = 0.1943956651474105 (1.3158e-05% change)
#     iteration    9: trace = 0.1943956577692682 (3.79543e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyevenfreqs:, 3, 0.0322581, 0, 0, 0.0322581, 0.182542, 0.251782, 0.312538
# elapsed time for k point: 1.2354559898376465
# solve_kpoint (0.0483871,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.1981479868087732 (0.0729483% change)
#     iteration    2: trace = 0.1981085022438873 (0.0199288% change)
#     iteration    3: trace = 0.1981026996247417 (0.00292905% change)
#     iteration    4: trace = 0.1980976931926197 (0.00252722% change)
#     iteration    5: trace = 0.198096200824622 (0.000753352% change)
#     iteration    6: trace = 0.1980956711765997 (0.000267369% change)
#     iteration    7: trace = 0.1980955622489228 (5.49874e-05% change)
#     iteration    8: trace = 0.1980955205815096 (2.1034e-05% change)
#     iteration    9: trace = 0.1980955045804082 (8.07747e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyevenfreqs:, 4, 0.0483871, 0, 0, 0.0483871, 0.185775, 0.254316, 0.314494
# elapsed time for k point: 1.2388761043548584
# solve_kpoint (0.0645161,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2033216022648845 (0.0679843% change)
#     iteration    2: trace = 0.2032838524154088 (0.0185683% change)
#     iteration    3: trace = 0.2032784403753292 (0.00266234% change)
#     iteration    4: trace = 0.2032739164465963 (0.00222551% change)
#     iteration    5: trace = 0.2032725124788326 (0.00069068% change)
#     iteration    6: trace = 0.2032719688371686 (0.000267445% change)
#     iteration    7: trace = 0.2032718396441184 (6.35568e-05% change)
#     iteration    8: trace = 0.2032717781463418 (3.0254e-05% change)
#     iteration    9: trace = 0.2032717543579536 (1.17028e-05% change)
#     iteration   10: trace = 0.20327175059076 (1.85328e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyevenfreqs:, 5, 0.0645161, 0, 0, 0.0645161, 0.190205, 0.257821, 0.31721
# elapsed time for k point: 1.3600728511810303
# solve_kpoint (0.0806452,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.209967453410859 (0.0622099% change)
#     iteration    2: trace = 0.2099317354065427 (0.0170127% change)
#     iteration    3: trace = 0.2099267565015752 (0.00237171% change)
#     iteration    4: trace = 0.2099227636236273 (0.00190205% change)
#     iteration    5: trace = 0.2099214948732981 (0.000604391% change)
#     iteration    6: trace = 0.2099209373366945 (0.000265593% change)
#     iteration    7: trace = 0.2099207759815136 (7.68648e-05% change)
#     iteration    8: trace = 0.2099206891070153 (4.13844e-05% change)
#     iteration    9: trace = 0.2099206596255815 (1.40441e-05% change)
#     iteration   10: trace = 0.2099206569040634 (1.29645e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyevenfreqs:, 6, 0.0806452, 0, 0, 0.0806452, 0.195746, 0.262257, 0.320664
# elapsed time for k point: 1.3526740074157715
# solve_kpoint (0.0967742,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2180806048271164 (0.0560826% change)
#     iteration    2: trace = 0.2180470360544396 (0.015394% change)
#     iteration    3: trace = 0.2180424660415837 (0.00209591% change)
#     iteration    4: trace = 0.2180390497847654 (0.0015668% change)
#     iteration    5: trace = 0.2180379391079689 (0.000509395% change)
#     iteration    6: trace = 0.2180373911423636 (0.000251317% change)
#     iteration    7: trace = 0.2180372058226495 (8.49945e-05% change)
#     iteration    8: trace = 0.218037097289337 (4.97774e-05% change)
#     iteration    9: trace = 0.2180370656864372 (1.44943e-05% change)
#     iteration   10: trace = 0.2180370634825127 (1.0108e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyevenfreqs:, 7, 0.0967742, 0, 0, 0.0967742, 0.202301, 0.267576, 0.32483
# elapsed time for k point: 1.341413974761963
# solve_kpoint (0.112903,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2276545057248114 (0.0499878% change)
#     iteration    2: trace = 0.2276230196802151 (0.0138316% change)
#     iteration    3: trace = 0.2276187796940924 (0.00186274% change)
#     iteration    4: trace = 0.2276158960960724 (0.00126686% change)
#     iteration    5: trace = 0.227614969478457 (0.000407098% change)
#     iteration    6: trace = 0.2276144559107475 (0.00022563% change)
#     iteration    7: trace = 0.2276142517458493 (8.96977e-05% change)
#     iteration    8: trace = 0.2276141257276223 (5.53648e-05% change)
#     iteration    9: trace = 0.2276140942156678 (1.38445e-05% change)
#     iteration   10: trace = 0.2276140919892672 (9.78147e-07% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyevenfreqs:, 8, 0.112903, 0, 0, 0.112903, 0.209769, 0.273726, 0.329675
# elapsed time for k point: 1.3419709205627441
# solve_kpoint (0.129032,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2386804193220713 (0.0442464% change)
#     iteration    2: trace = 0.2386507609797528 (0.0124267% change)
#     iteration    3: trace = 0.2386467015617835 (0.001701% change)
#     iteration    4: trace = 0.2386442474508679 (0.00102835% change)
#     iteration    5: trace = 0.2386435088575651 (0.000309496% change)
#     iteration    6: trace = 0.2386430591273334 (0.000188453% change)
#     iteration    7: trace = 0.2386428493064177 (8.79225e-05% change)
#     iteration    8: trace = 0.23864271473311 (5.63911e-05% change)
#     iteration    9: trace = 0.238642684455267 (1.26875e-05% change)
#     iteration   10: trace = 0.2386426816179273 (1.18895e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyevenfreqs:, 9, 0.129032, 0, 0, 0.129032, 0.218046, 0.28065, 0.335163
# elapsed time for k point: 1.3886699676513672
# solve_kpoint (0.145161,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.251146787490145 (0.0390927% change)
#     iteration    2: trace = 0.2511185026630428 (0.0112629% change)
#     iteration    3: trace = 0.2511143818098231 (0.00164101% change)
#     iteration    4: trace = 0.2511121989454066 (0.000869275% change)
#     iteration    5: trace = 0.2511116198012668 (0.000230632% change)
#     iteration    6: trace = 0.2511112526701894 (0.000146202% change)
#     iteration    7: trace = 0.251111057818961 (7.75956e-05% change)
#     iteration    8: trace = 0.2511109301793237 (5.083e-05% change)
#     iteration    9: trace = 0.2511109015219318 (1.14122e-05% change)
#     iteration   10: trace = 0.2511108977792671 (1.49044e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zevenyevenfreqs:, 10, 0.145161, 0, 0, 0.145161, 0.227035, 0.28829, 0.341255
# elapsed time for k point: 1.3716647624969482
# solve_kpoint (0.16129,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2650382245875442 (0.0346861% change)
#     iteration    2: trace = 0.2650106247723267 (0.0104141% change)
#     iteration    3: trace = 0.265006063982613 (0.001721% change)
#     iteration    4: trace = 0.2650039489641344 (0.000798105% change)
#     iteration    5: trace = 0.2650034686953432 (0.000181231% change)
#     iteration    6: trace = 0.2650031741256398 (0.000111157% change)
#     iteration    7: trace = 0.2650030105597868 (6.17222e-05% change)
#     iteration    8: trace = 0.2650029094271891 (3.81628e-05% change)
#     iteration    9: trace = 0.2650028850637826 (9.19364e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyevenfreqs:, 11, 0.16129, 0, 0, 0.16129, 0.236641, 0.296586, 0.347908
# elapsed time for k point: 1.2648282051086426
# solve_kpoint (0.177419,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.280333934123867 (0.031139% change)
#     iteration    2: trace = 0.2803060042581301 (0.00996357% change)
#     iteration    3: trace = 0.2803004557687199 (0.00197946% change)
#     iteration    4: trace = 0.2802981687284241 (0.000815928% change)
#     iteration    5: trace = 0.2802976961381698 (0.000168603% change)
#     iteration    6: trace = 0.2802974267828309 (9.60962e-05% change)
#     iteration    7: trace = 0.280297284489734 (5.07651e-05% change)
#     iteration    8: trace = 0.2802972180562767 (2.37011e-05% change)
#     iteration    9: trace = 0.2802972035115427 (5.18904e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyevenfreqs:, 12, 0.177419, 0, 0, 0.177419, 0.246779, 0.305483, 0.355074
# elapsed time for k point: 1.2251927852630615
# solve_kpoint (0.193548,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.2970054706530958 (0.0285348% change)
#     iteration    2: trace = 0.2969756770538793 (0.0100318% change)
#     iteration    3: trace = 0.2969681099461219 (0.00254809% change)
#     iteration    4: trace = 0.2969652863337735 (0.000950818% change)
#     iteration    5: trace = 0.2969647096563657 (0.00019419% change)
#     iteration    6: trace = 0.2969643911141108 (0.000107266% change)
#     iteration    7: trace = 0.2969642426237226 (5.00028e-05% change)
#     iteration    8: trace = 0.2969641979582411 (1.50407e-05% change)
#     iteration    9: trace = 0.296964195430713 (8.51122e-07% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zevenyevenfreqs:, 13, 0.193548, 0, 0, 0.193548, 0.257368, 0.314923, 0.362698
# elapsed time for k point: 1.2235140800476074
# solve_kpoint (0.209677,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3150122635502987 (0.0269593% change)
#     iteration    2: trace = 0.3149782828946768 (0.0107877% change)
# ...
# solve_kpoint (0.290323,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3464354237816323 (0.0399505% change)
#     iteration    2: trace = 0.3463654162070704 (0.02021% change)
#     iteration    3: trace = 0.3463495721161871 (0.00457449% change)
#     iteration    4: trace = 0.3463443596624335 (0.00150498% change)
#     iteration    5: trace = 0.3463438028173255 (0.000160778% change)
#     iteration    6: trace = 0.3463435596753904 (7.02025e-05% change)
#     iteration    7: trace = 0.3463434613849478 (2.83795e-05% change)
#     iteration    8: trace = 0.3463434159628794 (1.31147e-05% change)
#     iteration    9: trace = 0.3463434156627281 (8.66629e-08% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zoddyevenfreqs:, 19, 0.290323, 0, 0, 0.290323, 0.281011, 0.348531, 0.381972
# elapsed time for k point: 1.3061351776123047
# solve_kpoint (0.306452,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3705865567430017 (0.0408857% change)
#     iteration    2: trace = 0.3705080333909692 (0.0211912% change)
#     iteration    3: trace = 0.3704895578492032 (0.00498667% change)
#     iteration    4: trace = 0.3704834021932405 (0.00166151% change)
#     iteration    5: trace = 0.370482560990988 (0.000227056% change)
#     iteration    6: trace = 0.3704821277897545 (0.000116929% change)
#     iteration    7: trace = 0.3704819352225433 (5.19775e-05% change)
#     iteration    8: trace = 0.3704818267522559 (2.92782e-05% change)
#     iteration    9: trace = 0.3704818194009156 (1.98426e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zoddyevenfreqs:, 20, 0.306452, 0, 0, 0.306452, 0.295431, 0.357413, 0.394282
# elapsed time for k point: 1.2736430168151855
# solve_kpoint (0.322581,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.3956430620884315 (0.0416797% change)
#     iteration    2: trace = 0.3955551898934286 (0.0222124% change)
#     iteration    3: trace = 0.3955328659022737 (0.00564387% change)
#     iteration    4: trace = 0.3955248283516954 (0.0020321% change)
#     iteration    5: trace = 0.3955230228402455 (0.000456486% change)
#     iteration    6: trace = 0.3955218121513199 (0.000306099% change)
#     iteration    7: trace = 0.3955211600770336 (0.000164864% change)
#     iteration    8: trace = 0.3955207207293233 (0.000111081% change)
#     iteration    9: trace = 0.3955206412943185 (2.00837e-05% change)
#     iteration   10: trace = 0.3955206183773924 (5.79412e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zoddyevenfreqs:, 21, 0.322581, 0, 0, 0.322581, 0.309369, 0.366496, 0.406807
# elapsed time for k point: 1.3617300987243652
# solve_kpoint (0.33871,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4215166354171704 (0.042961% change)
#     iteration    2: trace = 0.4214141883446968 (0.0243073% change)
#     iteration    3: trace = 0.4213819641774494 (0.00764697% change)
#     iteration    4: trace = 0.4213665666166382 (0.00365413% change)
#     iteration    5: trace = 0.4213582386771494 (0.00197643% change)
#     iteration    6: trace = 0.4213512260329905 (0.00166431% change)
#     iteration    7: trace = 0.4213470693197503 (0.000986525% change)
#     iteration    8: trace = 0.4213442402565282 (0.000671435% change)
#     iteration    9: trace = 0.4213435311303228 (0.000168301% change)
#     iteration   10: trace = 0.4213432563017037 (6.52268e-05% change)
#     iteration   11: trace = 0.4213431306542506 (2.98207e-05% change)
#     iteration   12: trace = 0.421343082193981 (1.15014e-05% change)
#     iteration   13: trace = 0.421343028734896 (1.26878e-05% change)
#     iteration   14: trace = 0.4213430181169535 (2.52002e-06% change)
# Finished solving for bands 1 to 3 after 14 iterations.
# zoddyevenfreqs:, 22, 0.33871, 0, 0, 0.33871, 0.322655, 0.375906, 0.419442
# elapsed time for k point: 1.8592240810394287
# solve_kpoint (0.354839,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4479526403452597 (0.0489558% change)
#     iteration    2: trace = 0.447793790172125 (0.0354677% change)
#     iteration    3: trace = 0.4476917295134254 (0.0227945% change)
#     iteration    4: trace = 0.4475908822804997 (0.0225286% change)
#     iteration    5: trace = 0.4474526815283001 (0.0308813% change)
#     iteration    6: trace = 0.4473207497445453 (0.0294894% change)
#     iteration    7: trace = 0.4472391398408085 (0.0182458% change)
#     iteration    8: trace = 0.4471830423283237 (0.0125439% change)
#     iteration    9: trace = 0.4471649792769188 (0.00403938% change)
#     iteration   10: trace = 0.4471571363299074 (0.00175394% change)
#     iteration   11: trace = 0.4471542325837913 (0.000649381% change)
#     iteration   12: trace = 0.4471527875277771 (0.000323168% change)
#     iteration   13: trace = 0.4471517061897197 (0.000241828% change)
#     iteration   14: trace = 0.4471514759279039 (5.14952e-05% change)
#     iteration   15: trace = 0.4471513813918672 (2.11418e-05% change)
#     iteration   16: trace = 0.4471513157562748 (1.46786e-05% change)
#     iteration   17: trace = 0.4471512729894289 (9.56429e-06% change)
# Finished solving for bands 1 to 3 after 17 iterations.
# zoddyevenfreqs:, 23, 0.354839, 0, 0, 0.354839, 0.335086, 0.385812, 0.431298
# elapsed time for k point: 2.2433969974517822
# solve_kpoint (0.370968,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4711079729981419 (0.137539% change)
#     iteration    2: trace = 0.4698645591389141 (0.264283% change)
#     iteration    3: trace = 0.4679230737956606 (0.414057% change)
#     iteration    4: trace = 0.4663645552909322 (0.333627% change)
#     iteration    5: trace = 0.4655462104423796 (0.175627% change)
#     iteration    6: trace = 0.4651295087420241 (0.0895482% change)
#     iteration    7: trace = 0.4649903884908512 (0.0299145% change)
#     iteration    8: trace = 0.4649146922968661 (0.0162804% change)
#     iteration    9: trace = 0.4648936709129851 (0.00452166% change)
#     iteration   10: trace = 0.4648849944699337 (0.00186635% change)
#     iteration   11: trace = 0.4648813720476362 (0.000779211% change)
#     iteration   12: trace = 0.4648794466175564 (0.000414178% change)
#     iteration   13: trace = 0.4648776992644753 (0.000375873% change)
#     iteration   14: trace = 0.4648768950262122 (0.000173% change)
#     iteration   15: trace = 0.4648762596639354 (0.000136673% change)
#     iteration   16: trace = 0.4648756205391151 (0.000137483% change)
#     iteration   17: trace = 0.4648752153988205 (8.71503e-05% change)
#     iteration   18: trace = 0.4648748875143743 (7.05317e-05% change)
#     iteration   19: trace = 0.464874773698249 (2.44832e-05% change)
#     iteration   20: trace = 0.4648747297220421 (9.4598e-06% change)
# Finished solving for bands 1 to 3 after 20 iterations.
# zoddyevenfreqs:, 24, 0.370968, 0, 0, 0.370968, 0.346461, 0.396376, 0.433273
# elapsed time for k point: 2.6877880096435547
# solve_kpoint (0.387097,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4795562658262152 (0.0786885% change)
#     iteration    2: trace = 0.4793190004304091 (0.0494883% change)
#     iteration    3: trace = 0.479202916693704 (0.0242214% change)
#     iteration    4: trace = 0.479138981765551 (0.0133428% change)
#     iteration    5: trace = 0.479110882935646 (0.00586461% change)
#     iteration    6: trace = 0.4790919715055229 (0.00394727% change)
#     iteration    7: trace = 0.4790859355425655 (0.00125988% change)
#     iteration    8: trace = 0.4790825124129501 (0.000714515% change)
#     iteration    9: trace = 0.4790815842100502 (0.000193746% change)
#     iteration   10: trace = 0.4790812830924113 (6.28531e-05% change)
#     iteration   11: trace = 0.479081085109946 (4.13255e-05% change)
#     iteration   12: trace = 0.479081014452981 (1.47484e-05% change)
#     iteration   13: trace = 0.4790810016969942 (2.66259e-06% change)
# Finished solving for bands 1 to 3 after 13 iterations.
# zoddyevenfreqs:, 25, 0.387097, 0, 0, 0.387097, 0.356646, 0.407645, 0.430941
# elapsed time for k point: 1.7466199398040771
# solve_kpoint (0.403226,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.4934373520083252 (0.0654393% change)
#     iteration    2: trace = 0.493285656009763 (0.0307474% change)
#     iteration    3: trace = 0.4932464721978032 (0.00794375% change)
#     iteration    4: trace = 0.4932303496300289 (0.00326872% change)
#     iteration    5: trace = 0.4932252777653566 (0.0010283% change)
#     iteration    6: trace = 0.4932219471880181 (0.000675267% change)
#     iteration    7: trace = 0.4932209861998667 (0.000194839% change)
#     iteration    8: trace = 0.4932205278490248 (9.29302e-05% change)
#     iteration    9: trace = 0.4932204270263883 (2.04417e-05% change)
#     iteration   10: trace = 0.4932204080517781 (3.84709e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zoddyevenfreqs:, 26, 0.403226, 0, 0, 0.403226, 0.365621, 0.419021, 0.428909
# elapsed time for k point: 1.3645341396331787
# solve_kpoint (0.419355,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.5076558619340712 (0.0622657% change)
#     iteration    2: trace = 0.507517320199188 (0.0272942% change)
#     iteration    3: trace = 0.5074880565133215 (0.00576621% change)
#     iteration    4: trace = 0.5074771113834895 (0.00215675% change)
#     iteration    5: trace = 0.507473904886467 (0.000631853% change)
#     iteration    6: trace = 0.5074718401058207 (0.000406875% change)
#     iteration    7: trace = 0.5074712950679187 (0.000107403% change)
#     iteration    8: trace = 0.507471086350244 (4.1129e-05% change)
#     iteration    9: trace = 0.5074710617905622 (4.83962e-06% change)
# Finished solving for bands 1 to 3 after 9 iterations.
# zoddyevenfreqs:, 27, 0.419355, 0, 0, 0.419355, 0.373474, 0.423023, 0.434787
# elapsed time for k point: 1.2414579391479492
# solve_kpoint (0.435484,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.5220340073206581 (0.0607241% change)
#     iteration    2: trace = 0.521897359251507 (0.0261795% change)
#     iteration    3: trace = 0.5218689059672066 (0.00545204% change)
#     iteration    4: trace = 0.5218574514771883 (0.00219492% change)
#     iteration    5: trace = 0.5218531766750194 (0.000819155% change)
#     iteration    6: trace = 0.5218500631594997 (0.000596629% change)
#     iteration    7: trace = 0.5218491050998757 (0.000183589% change)
#     iteration    8: trace = 0.5218486859573501 (8.03188e-05% change)
#     iteration    9: trace = 0.5218485964078922 (1.716e-05% change)
#     iteration   10: trace = 0.5218485827554789 (2.61616e-06% change)
# Finished solving for bands 1 to 3 after 10 iterations.
# zoddyevenfreqs:, 28, 0.435484, 0, 0, 0.435484, 0.380341, 0.420406, 0.447714
# elapsed time for k point: 1.3662779331207275
# solve_kpoint (0.451613,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.5365167480803603 (0.0601883% change)
#     iteration    2: trace = 0.5363744140371969 (0.0265328% change)
#     iteration    3: trace = 0.536339959156608 (0.00642387% change)
#     iteration    4: trace = 0.5363222862132107 (0.00329516% change)
#     iteration    5: trace = 0.536312298662235 (0.00186225% change)
#     iteration    6: trace = 0.5363042306424105 (0.00150436% change)
#     iteration    7: trace = 0.5363016609956989 (0.000479141% change)
#     iteration    8: trace = 0.5363004729734873 (0.000221522% change)
#     iteration    9: trace = 0.5363001513581952 (5.99693e-05% change)
#     iteration   10: trace = 0.5363000574541352 (1.75096e-05% change)
#     iteration   11: trace = 0.5362999956097019 (1.15317e-05% change)
#     iteration   12: trace = 0.5362999741883054 (3.99429e-06% change)
# Finished solving for bands 1 to 3 after 12 iterations.
# zoddyevenfreqs:, 29, 0.451613, 0, 0, 0.451613, 0.38634, 0.417157, 0.461543
# elapsed time for k point: 1.6161961555480957
# solve_kpoint (0.467742,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.5509565829700106 (0.0617204% change)
#     iteration    2: trace = 0.5507912442406981 (0.0300139% change)
#     iteration    3: trace = 0.5507296193053776 (0.0111891% change)
#     iteration    4: trace = 0.5506824917945389 (0.00855765% change)
#     iteration    5: trace = 0.5506433921339144 (0.00710047% change)
#     iteration    6: trace = 0.5506130496807842 (0.00551052% change)
#     iteration    7: trace = 0.5506035572077073 (0.001724% change)
#     iteration    8: trace = 0.5505990855915915 (0.000812133% change)
#     iteration    9: trace = 0.5505976648878497 (0.000258029% change)
#     iteration   10: trace = 0.5505971497275666 (9.35639e-05% change)
#     iteration   11: trace = 0.5505968739724886 (5.00829e-05% change)
#     iteration   12: trace = 0.5505968167360173 (1.03954e-05% change)
#     iteration   13: trace = 0.550596795180327 (3.91497e-06% change)
# Finished solving for bands 1 to 3 after 13 iterations.
# zoddyevenfreqs:, 30, 0.467742, 0, 0, 0.467742, 0.391481, 0.413834, 0.47548
# elapsed time for k point: 1.7596721649169922
# solve_kpoint (0.483871,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.564739783301344 (0.0709754% change)
#     iteration    2: trace = 0.5644736049987195 (0.047144% change)
#     iteration    3: trace = 0.5642357224702927 (0.0421512% change)
#     iteration    4: trace = 0.5639569137310076 (0.0494257% change)
#     iteration    5: trace = 0.5636821496358988 (0.0487326% change)
#     iteration    6: trace = 0.5634921833999175 (0.0337066% change)
#     iteration    7: trace = 0.5634343213477927 (0.010269% change)
#     iteration    8: trace = 0.5634060626432257 (0.00501556% change)
#     iteration    9: trace = 0.5633961173564662 (0.00176522% change)
#     iteration   10: trace = 0.5633915433093042 (0.000811874% change)
#     iteration   11: trace = 0.5633888245105655 (0.000482578% change)
#     iteration   12: trace = 0.5633876071177708 (0.000216084% change)
#     iteration   13: trace = 0.5633866840223463 (0.000163847% change)
#     iteration   14: trace = 0.5633863253333641 (6.36666e-05% change)
#     iteration   15: trace = 0.5633861891169477 (2.41782e-05% change)
#     iteration   16: trace = 0.5633861271156502 (1.10051e-05% change)
#     iteration   17: trace = 0.5633861262453026 (1.54485e-07% change)
# Finished solving for bands 1 to 3 after 17 iterations.
# zoddyevenfreqs:, 31, 0.483871, 0, 0, 0.483871, 0.395474, 0.410885, 0.488016
# elapsed time for k point: 2.2690269947052
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 3...
#     iteration    1: trace = 0.5734467223451141 (0.125968% change)
#     iteration    2: trace = 0.5725018094561729 (0.164914% change)
#     iteration    3: trace = 0.5709219548056099 (0.276338% change)
#     iteration    4: trace = 0.5697209271597007 (0.210588% change)
#     iteration    5: trace = 0.5690358369647165 (0.120322% change)
#     iteration    6: trace = 0.5686979941349657 (0.0593887% change)
#     iteration    7: trace = 0.5686043794089027 (0.0164626% change)
#     iteration    8: trace = 0.5685480791714684 (0.00990197% change)
#     iteration    9: trace = 0.5685154084086286 (0.00574652% change)
#     iteration   10: trace = 0.5684819109416988 (0.00589227% change)
#     iteration   11: trace = 0.56845056670353 (0.00551383% change)
#     iteration   12: trace = 0.5684313175562055 (0.00338631% change)
#     iteration   13: trace = 0.5684197735474154 (0.00203087% change)
#     iteration   14: trace = 0.5684164032312089 (0.000592929% change)
#     iteration   15: trace = 0.5684146316535111 (0.000311669% change)
#     iteration   16: trace = 0.5684137597319355 (0.000153395% change)
#     iteration   17: trace = 0.5684134326458083 (5.75437e-05% change)
#     iteration   18: trace = 0.5684133539122911 (1.38515e-05% change)
#     iteration   19: trace = 0.5684133312677156 (3.98382e-06% change)
# Finished solving for bands 1 to 3 after 19 iterations.
# zoddyevenfreqs:, 32, 0.5, 0, 0, 0.5, 0.3972, 0.4095, 0.492905
# elapsed time for k point: 2.4905879497528076
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3972000076530759 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.24352547940373784 at Vector3<0.0, 0.0, 0.0> to 0.4230232559297925 at Vector3<0.4193548387096774, 0.0, 0.0>
# Band 3 range: 0.24776896327414064 at Vector3<0.0, 0.0, 0.0> to 0.49290485383521204 at Vector3<0.5, 0.0, 0.0>
# total elapsed time for run: 41.94094705581665
# done

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4.2))

x = range(len(yodd_zeven_freqs))
linewidth = 1.2
for i in range(yodd_zeven_freqs.shape[1]):
    if i==0:
        ax.plot(x, yodd_zeven_freqs[:,i], color='#EB262A', linestyle='-', lw=linewidth, label=r'$E_{(o)}$', zorder=1)
        ax.plot(x, yeven_zeven_freqs[:,i], color='#F07D31', linestyle='-', lw=linewidth, label=r'$E_{(e)}$', zorder=2)
        ax.plot(x, yeven_zodd_freqs[:,i], color='#343796', linestyle='-', lw=linewidth, label=r'$M_{(e)}$', zorder=3)
        ax.plot(x, yodd_zodd_freqs[:,i], color='#4DAAC2', linestyle='-', lw=linewidth, label=r'$M_{(o)}$', zorder=4)
    else:
        ax.plot(x, yodd_zeven_freqs[:,i], color='#EB262A', linestyle='-', lw=linewidth, zorder=1)
        ax.plot(x, yeven_zeven_freqs[:,i], color='#F07D31', linestyle='-', lw=linewidth, zorder=2)
        ax.plot(x, yeven_zodd_freqs[:,i], color='#343796', linestyle='-', lw=linewidth, zorder=3)
        ax.plot(x, yodd_zodd_freqs[:,i], color='#4DAAC2', linestyle='-', lw=linewidth, zorder=4)
        # ax.plot(x, yodd_zeven_freqs[:,i], 'o',color='r', markerfacecolor="none", ms=3)
ax.plot([x[0], x[-1]], [0, 0.5], color='#000000', linestyle='-', lw=2, zorder=5)
ax.fill_between(x, k_parallel/1, 0.5, facecolor='#9D9CCC', alpha=1, zorder=5)

ax.set_ylim([0, .5])
ax.set_xlim([x[0], x[-1]])

tick_locs = [0, len(k_points) - 1]
tick_labs = [r"$\Gamma$", "X"]
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=12)
ax.set_xlabel(r"Wave vector $ka/2\pi c$", size=12)
ax.set_ylabel(r"Frequency $\omega a/2\pi c$", size=12)
ax.legend(loc='best')
ax.text(2, 0.42, "Light Cone", color="w", zorder=6, size=15)

fig.tight_layout()
